# %% [markdown]
# # Guitar learning data
#
# Install dependencies from the repo root (`pip install -r requirements.txt`), then run the scripts under `analysis/` to regenerate figures. This notebook only loads and sanity-checks the CSV.

# %%
from pathlib import Path

import pandas as pd

repo = Path("..").resolve()
df = pd.read_csv(repo / "data" / "main-data.csv")
assert (df["clean_ratio"] - df["successful_trials"] / 4).abs().max() < 1e-9
df.head()
